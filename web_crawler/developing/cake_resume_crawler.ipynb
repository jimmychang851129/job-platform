# %% [markdown]
# ### 爬蟲思路和概念 :
# 1. 先去要爬取的網站，打開F12 DevTool查看先關資訊
# 2. 觀察自己想要爬取的資料，可以複製一段文字，到Elements中查看，放在HTML檔案種中的哪個地方
# 3. 觀察Html Tag 和 css屬性，搭配 BS4進行爬取資訊
#
# #### 範例
# **爬取CakeResume的職缺資訊**
# 1. 可以觀察到所有的職缺資訊都是使用div 把資料包起來的
# 2. 會發現資料被包在一個叫做`JobSearchPage_searchResults__*`的裡面
#
#     ![](https://i.imgur.com/iYC1npE.png)
# 3. 接著可以發現，所有的div container都叫做`JobSearchItem_Wrapper__*`，我們可以利用這個資訊進行資料的爬取
#
#     ![](https://i.imgur.com/tdhjgBG.png)
#
# 爬取過程參照下列作法

# %%
import requests
from bs4 import BeautifulSoup
import re
import json
import time

# %%
url = 'https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest'

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %%
searchResult = soup.find_all('div', class_ = re.compile(r'JobSearchPage_searchResults__*'))  
searchList = soup.find_all('div', class_ = re.compile(r'JobSearchHits_list__*'))
searchItem = soup.find_all('div', class_ = re.compile(r'JobSearchItem_wrapper__*'))
len(searchItem)  # 表示這頁中有13個職缺資料，後續須對這些資料進行清洗
# Out:
# 10

# %% [markdown]
# ### 查看div 中的資料樣態
# 1. 職稱: 放在`JobSearchItem_headerTitle__*`
# 2. 公司名稱: 放在`JobSearchItem_headerSubtitle__*`
# 3. 公司簡介: 放在`JobSearchItem_description__*`
# 4. Job tag: 放在`JobSearchItem_tags__*`
# 5. 職缺性質: 放在`JobSearchItem_features__*`

# %%
processing = searchItem[0]
url_domain = 'https://www.cakeresume.com'
job_link = url_domain + (processing.find('div', class_ = re.compile(r'JobSearchItem_headerTitle__*')).find('a', href = True))['href']
job_title = processing.find('div', class_ = re.compile(r'JobSearchItem_headerTitle__*')).getText()
company = processing.find('div', class_ = re.compile(r'JobSearchItem_headerSubtitle__*')).getText()
important_skill = []
tags = processing.find('div', class_ = re.compile(r'JobSearchItem_tags__*'))
if tags:
    tags = tags.find_all('div', class_ = re.compile(r'Tags_item__*'))
    for tag in tags:
        if tag.text != '':
            important_skill.append(tag.text)

    jon_feature_soup = processing.find('div', class_ = re.compile(r'JobSearchItem_features__*'))

# %%
print(job_link)
print(job_title)
print(company)
print(important_skill)
# Out:
# https://www.cakeresume.com/companies/realtek-semiconductor/jobs/b8b624
# PC Camera演算法開發工程師/專案技術主管(臺北大直)
# Realtek 瑞昱半導體
# ['C/C++', 'Matlab', 'Camera']

# %%
job_feature_soup = processing.find('div', class_ = re.compile(r'JobSearchItem_features__*'))
inline_messages_type = job_feature_soup.find_all('div', class_ = re.compile(r'InlineMessage_icon__*'))
inline_messages = job_feature_soup.find_all('div', class_ = re.compile(r'InlineMessage_label__*'))
print(f'tpye: {len(inline_messages_type)} label: {len(inline_messages)}')
print(inline_messages)
# Out:
# tpye: 5 label: 5
# [<div class="InlineMessage_label__hP3Fk">1<div class="SeparatorDot_dot__rrEYX">・</div><div class="JobSearchItem_featureSegments__I1Csc"><div><a class="Button_button__N4TAn Button_buttonLinkGreen__i7ru_ Button_buttonSmall__PsSMK Button_buttonNoPadding___8Dm0" href="/jobs?profession%5B0%5D=it_data-engineer&amp;job_type%5B0%5D=full_time&amp;order=latest"><div class="Button_buttonContent__arBxx"><div class="Button_buttonContentMain__afmnj">Full-time</div></div></a></div><div class="SeparatorDot_dot__rrEYX">・</div><div><a class="Button_button__N4TAn Button_buttonLinkGreen__i7ru_ Button_buttonSmall__PsSMK Button_buttonNoPadding___8Dm0" href="/jobs?profession%5B0%5D=it_data-engineer&amp;seniority_level%5B0%5D=mid_senior_level&amp;order=latest"><div class="Button_buttonContent__arBxx"><div class="Button_buttonContentMain__afmnj">Mid-Senior level</div></div></a></div></div></div>, <div class="InlineMessage_label__hP3Fk"><div class="JobSearchItem_featureSegments__I1Csc"><a class="JobSearchItem_featureSegmentLink__0qG7L" href="/jobs?location_list%5B0%5D=%E5%8F%B0%E7%81%A3%E5%8F%B0%E5%8C%97&amp;profession%5B0%5D=it_data-engineer&amp;order=latest">台灣台北</a></div></div>, <div class="InlineMessage_label__hP3Fk">90K ~ 150K TWD / month</div>, <div class="InlineMessage_label__hP3Fk">3 years of experience required</div>, <div class="InlineMessage_label__hP3Fk">Managing 1-5 staff</div>]

# %%
for inline_message in inline_messages_type:
    class_type = inline_message.find('div', class_ = re.compile(r'Tooltip_handle__*')).find('i', class_ = True)['class']
    print(class_type[1][3:])
# Out:
# user
# map-marker-alt
# dollar-sign
# business-time
# sitemap

# %%
for inline_message in inline_messages:
    print(inline_message.text)
# Out:
# 1・Full-time・Mid-Senior level
# 台灣台北
# 90K ~ 150K TWD / month
# 3 years of experience required
# Managing 1-5 staff

# %%
feature = {}
if len(inline_messages) == len(inline_messages_type):
    for i in range(len(inline_messages)):
        type = (inline_messages_type[i].find('div', class_ = re.compile(r'Tooltip_handle__*')).find('i', class_ = True)['class'])[1][3:]
        label = inline_messages[i].text
        feature[type] = label

feature
# Out:
# {'user': '1・Full-time・Mid-Senior level',
#  'map-marker-alt': '台灣台北',
#  'dollar-sign': '90K ~ 150K TWD / month',
#  'business-time': '3 years of experience required',
#  'sitemap': 'Managing 1-5 staff'}

# %% [markdown]
# 爬蟲程式設計，建立爬蟲Pipline以及資料清洗及整理的方式

# %%
def get_soup(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, "html.parser")
    if soup:
        print("Success")
        return soup
    else:
        print("Fail")
        return None

def get_searchItem(soup):
    searchItem = soup.find_all('div', class_ = re.compile(r'JobSearchItem_wrapper__*'))
    print(f"There are {len(searchItem)} jobs in this page.")
    return searchItem

def get_job_link_and_title(item):
    url_domain = 'https://www.cakeresume.com'
    job_title = item.find('div', class_ = re.compile(r'JobSearchItem_headerTitle__*')).getText()
    job_link = url_domain + (item.find('div', class_ = re.compile(r'JobSearchItem_headerTitle__*')).find('a', href = True))['href']
    return job_link, job_title

def get_company_name(item):
    company_name = item.find('div', class_ = re.compile(r'JobSearchItem_headerSubtitle__*')).getText()
    return company_name

def get_skill_set(item):
    if item.find('div', class_ = re.compile(r'JobSearchItem_tags__*')):
        skill_set = []
        tags = item.find('div', class_ = re.compile(r'JobSearchItem_tags__*')).find_all('div', class_ = re.compile(r'Tags_item__*'))
        for tag in tags:
            if tag.text != '':
                skill_set.append(tag.text)
        return skill_set
    else:
        return ""

def get_feature(item):
    job_features = item.find('div', class_ = re.compile(r'JobSearchItem_features__*'))
    inline_messages_type = job_feature_soup.find_all('div', class_ = re.compile(r'InlineMessage_icon__*'))
    inline_messages = job_feature_soup.find_all('div', class_ = re.compile(r'InlineMessage_label__*'))  
    print(f'type: {len(inline_messages_type)}  label: {len(inline_messages)}')
    feature = {}
    if len(inline_messages) == len(inline_messages_type):
        for i in range(len(inline_messages)):
            type = (inline_messages_type[i].find('div', class_ = re.compile(r'Tooltip_handle__*')).find('i', class_ = True)['class'])[1][3:]
            label = inline_messages[i].text
            feature[type] = label
    print(feature)
    return feature

def arrange_the_data(job_link, job_title, company_name, skill_set, feature):
    job_info = []
    if job_link != "":
        job_info.append(job_link)
    else:
        job_info.append("")

    if job_title != "":
        job_info.append(job_title)
    else:
        job_info.append("")   

    if company_name != "":
        job_info.append(company_name)
    else:
        job_info.append("")
        
    if skill_set != "":
        job_info.append(skill_set)
    else:
        job_info.append("")
        
    if "user" in feature.keys():
        job_info.append(feature['user'])
    else:
        job_info.append("")
        
    if "map-marker-alt" in feature.keys():
        job_info.append(feature['map-marker-alt'])
    else:
        job_info.append("")     
           
    if "dollar-sign" in feature.keys():
        job_info.append(feature['dollar-sign'])
    else:
        job_info.append("")        

    if "business-time" in feature.keys():
        job_info.append(feature['business-time'])
    else:
        job_info.append("")        

    if "sitemap" in feature.keys():
        job_info.append(feature['sitemap'])
    else:
        job_info.append("")        

    return job_info

# %%
# url = "https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest"


def get_job_info(url):
    soup = get_soup(url)
    if soup != "":
        searchItems = get_searchItem(soup)
        job_infos = []
        for search_item in searchItems:
            job_link, job_title = get_job_link_and_title(search_item)
            company_name = get_company_name(search_item)
            skill_set = get_skill_set(search_item)
            feature = get_feature(search_item)
            job_info = arrange_the_data(job_link, job_title, company_name, skill_set, feature)
            job_infos.append(job_info)
            print(job_info)

# %% [markdown]
# 設計非日常爬蟲，初始化時該如何找到下一頁的function
# 我們的思路是每次進到一個爬蟲頁面後，找到下一頁的網址，直到找不到為止。
# 一樣借由開發人員工具(F12)來檢視網頁的規律，會發現頁碼的資訊放在`JobSearchPage_searchPagination__*`，
#
# ![](https://i.imgur.com/ldb3F5v.png)
#
# 接著我們可以發現，`>`下一頁符號的資訊放在`Pagination_itemNavigation__*`中href中。
#
# ![](https://i.imgur.com/VF6PebC.png)

# %%
url = 'https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest'

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

next_page = soup.find('div', class_ = re.compile(r'Pagination_wrapper__*'))
next_page
# Out:
# <div class="Pagination_wrapper__AEWI_"><div class="Pagination_itemNavigation__wHk0M Pagination_itemDisabled__jrhUA"><i class="fa fa-chevron-left"></i></div><a class="Pagination_itemNumber__5L1fV Pagination_itemActive___SZIW" href="https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest">1</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest&amp;page=2">2</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest&amp;page=3">3</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest&amp;page=4">4</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest&amp;page=5">5</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest&amp;page=6">6</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest&amp;page=7">7</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest&amp;page=8">8</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest&amp;page=9">9</a><div class="Pagination_itemEllipsis__WiU0R"><i class="fa fa-ellipsis-h"></i></div><a class="Pagination_itemNavigation__wHk0M" href="https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest&amp;page=2"><i class="fa fa-chevron-right"></i></a></div>

# %%
next_page_link = next_page.find_all('a', class_ = re.compile(r'Pagination_itemNavigation__*'), href = True)
next_page_link[0]['href']
# Out:
# 'https://www.cakeresume.com/jobs/categories/it/data-engineer?order=latest&page=2'

# %%
# Check if there is no next page
url = 'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=2'

response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

next_page = soup.find('div', class_ = re.compile(r'Pagination_wrapper__*'))
next_page
# Out:
# <div class="Pagination_wrapper__AEWI_"><a class="Pagination_itemNavigation__wHk0M" href="https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&amp;order=latest"><i class="fa fa-chevron-left"></i></a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&amp;order=latest">1</a><a class="Pagination_itemNumber__5L1fV Pagination_itemActive___SZIW" href="https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&amp;order=latest&amp;page=2">2</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&amp;order=latest&amp;page=3">3</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&amp;order=latest&amp;page=4">4</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&amp;order=latest&amp;page=5">5</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&amp;order=latest&amp;page=6">6</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&amp;order=latest&amp;page=7">7</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&amp;order=latest&amp;page=8">8</a><a class="Pagination_itemNumber__5L1fV" href="https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&amp;order=latest&amp;page=9">9</a><div class="Pagination_itemEllipsis__WiU0R"><i class="fa fa-ellipsis-h"></i></div><a class="Pagination_itemNavigation__wHk0M" href="https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&amp;order=latest&amp;page=3"><i class="fa fa-chevron-right"></i></a></div>

# %%
next_page_link = next_page.find_all('a', class_ = re.compile(r'Pagination_itemNavigation__*'))
next_page_link[1]['href']
# Out:
# 'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=3'

# %% [markdown]
# 設計初始化DB的爬蟲

# %%
def find_next_page(soup):
    next_page = soup.find('div', class_ = re.compile(r'Pagination_wrapper__*'))
    next_page_link = next_page.find_all('a', class_ = re.compile(r'Pagination_itemNavigation__*'), href = True)
    if next_page_link:
        if len(next_page_link) == 2:
            return next_page_link[1]['href']
        else :
            return next_page_link[0]['href']
    else:
        next_page_link = next_page.find_all('a', class_ = re.compile(r'Pagination_itemNumber__*'), href = True)
        return next_page_link[0]['href']

# %%
job_types = ['it_back-end-engineer', 'it_data-engineer', 'it_data-scientist', 'it_machine-learning-engineer', 'it_qa-test-engineer', 'management-business_data-analyst']
location = 'latest'
url_data = []

for job_type in job_types:
    # time.sleep(10)
    url = f'https://www.cakeresume.com/jobs/python?profession%5B0%5D={job_type}&order={location}'
    url_data.append(url)
    soup = get_soup(url)
    while True:
        next_page_link = find_next_page(soup)
        if next_page_link in url_data:
            break
        else:
            url_data.append(next_page_link)
            soup = get_soup(next_page_link)
# Out:
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=2
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=3
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=4
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=5
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=6
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=7
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=8
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=9
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=10
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=11
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=12
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=13
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=14
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=13
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest&page=2
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest&page=3
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest&page=4
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest&page=5
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest&page=6
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest&page=7
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest&page=6
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-scientist&order=latest&page=2
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-scientist&order=latest&page=3
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-scientist&order=latest&page=4
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-scientist&order=latest&page=5
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-scientist&order=latest&page=4
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_machine-learning-engineer&order=latest&page=2
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_machine-learning-engineer&order=latest
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_qa-test-engineer&order=latest&page=2
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_qa-test-engineer&order=latest&page=3
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_qa-test-engineer&order=latest&page=4
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_qa-test-engineer&order=latest&page=5
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_qa-test-engineer&order=latest&page=4
# Success
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=management-business_data-analyst&order=latest

# %%
for url in url_data:
    print(url)
    get_job_info(url)
# Out:
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest
# Success
# There are 10 jobs in this page.
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/aha/jobs/backend-software-engineer-43ce76', '🔥  [資深] 後端軟體工程師 (全遠端)  🛠 Senior Back-End Engineer (Remote) 🚀', 'Aha', ['JavaScript', 'Node.js', 'Express.js'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/devcore/jobs/ffbb1e', 'Senior Developer 紅隊平台開發工程師', 'DEVCORE 戴夫寇爾', ['Ruby', 'Python', 'Web Developer'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/mai-ai/jobs/senior-backend-engineer-509322', '後端工程師 Senior Backend Engineer', '肯狄科研有限公司', ['Backend', 'game development', 'Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/paradise-soft/jobs/rd-backend-engineer-im', ' [RD] 後端工程師 (IM)', '天堂遊戲有限公司', ['JAVA', 'MySQL', 'JavaScript'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/paradise-soft/jobs/rd-senior-backend-engineer-im', '[RD] 資深後端工程師 (IM)', '天堂遊戲有限公司', ['JAVA', 'MySQL', 'JavaScript'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/paradise-soft/jobs/backend-engineer-f5f6dc', 'Backend Engineer 後端工程師', '天堂遊戲有限公司', ['JAVA', 'MySQL', 'JavaScript'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/paradise-soft/jobs/backend-engineer-backend-engineer-golang', 'Senior Backend Engineer 資深後端工程師 (Golang Engineer)', '天堂遊戲有限公司', ['JAVA', 'MySQL', 'JavaScript'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/circle-ai/jobs/web-backend-engineer-13e457', 'Web Backend Engineer (Web 後端工程師)', 'Circle AI', ['+python', '+node.js', '+Golang'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/xtars/jobs/python-backend-engineer-bb5add', 'Python 後端工程師', '星眺互動傳媒有限公司', ['Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/linkernetworks/jobs/web-backend-fullstack-engineer', '中階/資深後端工程師 Mid/Senior Backend Engineer (Python)', 'Linker Networks Inc. 美商寶蘊凌科網路科技有限公司台灣分公司', ['Python', 'django', 'PostgreSQL'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=2
# Success
# There are 10 jobs in this page.
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/linkernetworks/jobs/web-backend-fullstack-engineer', '中階/資深後端工程師 Mid/Senior Backend Engineer (Python)', 'Linker Networks Inc. 美商寶蘊凌科網路科技有限公司台灣分公司', ['Python', 'django', 'PostgreSQL'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/linkernetworks/jobs/web-back-end-engineer-2b0b3b', '中階/資深後端工程師 Mid/Senior Backend Engineer (Node.js)', 'Linker Networks Inc. 美商寶蘊凌科網路科技有限公司台灣分公司', ['GraphQL', 'JavaScript', 'TypeScript'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/seawardcard-ad4b2f/jobs/d87487', '知名紡織產業上市企業｜桃園觀音｜ 智慧應用工程師', '華卡企業股份有限公司', ['JAVA', 'C#', 'PHP'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/gliacloud/jobs/back-end-trainee-engineer-603ee1', '後端實習工程師', 'GliaCloud 集雅科技', ['Python', '人工智慧', 'AI'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/wondercise/jobs/rtos-Backend-engineer', 'Jr./Sr. Backend Engineer', 'Wondercise Technology Corp.', '', '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/xare/jobs/expanding-talents-junior-backend-engineer', '【擴大徵才】後端工程師 Junior Backend Engineer', '香港商宇晨品牌顧問有限公司台灣分公司', ['Linux', 'Git', 'PHP'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/xare/jobs/expanding-talents-senior-backend-engineer', '【擴大徵才】資深後端工程師 Senior Backend Engineer', '香港商宇晨品牌顧問有限公司台灣分公司', ['Linux', 'Git', 'PHP'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/quasar/jobs/junior-backend-engineer-0eb1d8', '後端工程師 Junior Backend Engineer', '健身管_類星體數位股份有限公司', ['Linux', 'Git', 'PHP'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/quasar/jobs/backend-engineer-e3f3fc', '資深後端工程師 Senior Backend Engineer', '健身管_類星體數位股份有限公司', ['Linux', 'Git', 'PHP'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/9ce1d0/jobs/python-engineer-591836', 'Python工程師', '米約科技有限公司', '', '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=3
# Success
# There are 10 jobs in this page.
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/tradingvalley/jobs/backend-system-development-engineer', '後端系統開發工程師', 'TradingValley', ['backend', 'Trading', 'Investment'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/futures-ai/jobs/backend-engineer-junior', '後端軟體工程師 (Junior/Mid)', '期天資訊有限公司', ['Python', 'Web', 'C#.NET'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/buyandship-19c54e/jobs/senior-backend-software-engineer-c6479e', 'Senior Backend Software Engineer', 'Buyandship 台灣', ['backend', 'Node.js', 'Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/appworks-school/jobs/47f50b', '［可兼職］Back-End Class Instructor (後端技術導師)', 'AppWorks School', ['back-end', 'education', 'instructor'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/statementdog/jobs/rails-backend-engineer-junior', 'Rails 後端工程師 (junior)', '財報狗資訊股份有限公司', ['後端', 'Ruby on Rails', 'Ruby'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/statementdog/jobs/rails-backend-engineer', 'Rails 後端工程師', '財報狗資訊股份有限公司', ['後端', 'Ruby on Rails', 'Ruby'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/viverse/jobs/backend-engineer-25a31c', 'Backend Engineer (Go / Node.js / Scala)', 'VIVERSE 宏願數位股份有限公司', ['後端工程師', 'Micro-Service', 'RESTful API'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/bebit-tech_/jobs/jr-backend-engineer', '(Jr.) Backend Engineer 後端工程師', 'beBit TECH_微拓科技股份有限公司', ['Django', 'Python', 'PostgreSQL'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/deepwave/jobs/ml-backend-developer-23b22b', 'Senior/Junior Back-end Engineer', 'DeepWave 迪威智能股份有限公司', ['Machine Learning', 'Python', 'Linux'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/zenpulsar-ltd/jobs/senior-back-end-python-developer-etl-focus', 'Senior Back-end Python Developer (ETL focus)', 'ZeNPulsar Ltd', ['Neo4jDB', 'MongoDB', 'Docker'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=4
# Success
# There are 10 jobs in this page.
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/mixerbox/jobs/0c6415', '【月薪 13 萬起】Backend Engineer：加入矽谷級研發團隊！', 'MixerBox', ['Backend', 'backend engineer', 'Backend Development'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/core-code-tech/jobs/back-end-working-students', '後端工讀生', '禾碼科技股份有限公司', ['Node.js', '.NET Core', 'Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/fundswap/jobs/php-ca4231', '好好證券-後端工程師 Backend Engineer (熟 Python、RESTful API )', '好好證券股份有限公司', ['Python', 'MySQL'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/proton/jobs/back-end-fullstack-developer-anti-abuse', 'Back End / Fullstack Developer (Anti-Abuse)', 'Proton 質子科技有限公司', ['React', 'jQuery', 'RESTful APIs'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/crescendo-lab/jobs/partner-engineer-openapi', 'Partner Engineer (OpenAPI)', '漸強實驗室 Crescendo Lab Ltd.', ['Python', 'Backend Development', 'startup'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/crescendo-lab/jobs/backend-developer-backend-engineer-581565', 'Backend Developer 後端工程師', '漸強實驗室 Crescendo Lab Ltd.', ['Python', 'Backend Development', 'startup'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/crescendo-lab/jobs/sr-backend-developer-senior-backend-engineer', 'Sr. Backend Developer 資深後端工程師', '漸強實驗室 Crescendo Lab Ltd.', ['Python', 'Backend Development', 'startup'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/aibdt/jobs/senior-backend-engineer-258389', '(資深)後端工程師', '昱峰智能大數據科技股份有限公司', ['Python', 'Git', 'API串接'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/kengoson/jobs/tw-backend', '(TW) Senior Back-end Engineer (Remote, 中文可)', 'Kengoson', ['Backend Development', 'Python', 'MySQL'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/blocktempo/jobs/backend-engineer-1dc28d', '後端工程師 Backend Developer', '動區動趨 BlockTempo', ['API', 'Mysql', 'Redis'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=5
# Success
# There are 10 jobs in this page.
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/cakeresume-recruitment-consulting/jobs/fefe34', 'Hot🔥 – 優質外商 Fintech Company 首批台灣團隊 look for Sr. Backend Engineer (Remote JOB!!)- NC', 'CakeResume Headhunting Recruitment Service', ['Java', 'Fintech', 'blockchain'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/cakeresume-recruitment-consulting/jobs/5c36a0', 'HOT🔥- Top USA Silicon Valley Company look for Sr. Backend Engineer- NC', 'CakeResume Headhunting Recruitment Service', ['Python', 'AIoT', 'Silicon Valley'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/maideax/jobs/python-backend-development-engineer', 'Python後端開發工程師', '麥睿資訊股份有限公司', ['python', 'Django', 'RESTful APIs'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/nextgen-hk/jobs/php-backend-engineer-backend-engineer', 'PHP 後端工程師 Backend Engineer', '創譽科技有限公司', ['Node.js', 'express', 'koa'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/gogolook/jobs/sr-backend-engineer-86dd45', 'Senior Backend Engineer', 'Gogolook ', ['Backend Development', 'SQL', 'AWS'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/rogersai/jobs/sr-software-engineer-backend-fb83b1', 'Sr. Software Engineer, Backend', '羅傑斯人工智能股份有限公司', ['Golang', 'Python', 'Web API'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/parenting-43613b/jobs/senior-back-end-engineer-2d4c60', '《天下雜誌群》PHP工程師', '天下雜誌股份有限公司', ['PHP', 'Laravel', 'Developer'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/numbersprotocol/jobs/senior-backend-engineer-25e01a', 'Senior Backend Engineer', 'Numbers Protocol (主張數據股份有限公司)', ['Python', 'JavaScript', 'Blockchain'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/numbersprotocol/jobs/junior-backend-engineer-b21615', 'Junior Backend Engineer', 'Numbers Protocol (主張數據股份有限公司)', ['Python', 'JavaScript', 'Backend Development'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/numbersprotocol/jobs/51048e', 'Decentralized Data System Development Internship 去中心化資料開發實習生', 'Numbers Protocol (主張數據股份有限公司)', ['blockchain', 'startup', 'Remote Working'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=6
# Success
# There are 10 jobs in this page.
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/mile.cloud/jobs/3c3e6b', '【CloudMile Intern Program】Backend Intern 後端實習生', 'CloudMile 萬里雲', ['Backend Development', 'Backend Engineer', 'Backend'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/jkopay/jobs/backend-engineer-d7a8c1', 'Backend engineer', '街口電子支付股份有限公司', ['Python', 'Django Framework', '.net framework'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/jkopay/jobs/senior-python-web-engineer', 'Senior backend developer(會計帳務清結算系統)', '街口電子支付股份有限公司', ['Python', 'MySQL', 'Django'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/tsaitung/jobs/backend-developer-junior-senior', 'Senior Backend Engineer', '菜蟲農食股份有限公司', ['Python', 'GCP', 'Flask'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/ANVO/jobs/python-engineer-ece357', 'Python工程師', 'ANDES ADVISORY INC.', ['Python', 'MySQL', 'Linux'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/onedegree/jobs/senior-software-engineer-ixt-client-backend', 'Senior Software Engineer, IXT Client (Backend)', 'OneDegree', ['Python', 'Backend Development'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/nextlink-cloud/jobs/backend-engineer-python-5ffb05', '後端工程師 (Python)', '博弘雲端科技股份有限公司', ['MSSQL', 'Python', 'Java'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/lativ/jobs/e5e4fb', '【新鮮人月薪 5萬起】人才培訓計畫：後端工程師', 'lativ', ['Golang', '.net', 'Java'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/symphox.net/jobs/xiaoshubu-backend-engineer-junior-senior', '[小樹購] 後端工程師 Backend Engineer(Junior/Senior ) ', '神坊資訊股份有限公司', ['PHP', 'Python', 'Java'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/symphox.net/jobs/c02b6a', '[小樹生活圈] 後端工程師 Backend Engineer (Junior/Senior)', '神坊資訊股份有限公司', ['Python', 'Django', 'Flask'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=7
# Success
# There are 10 jobs in this page.
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/getcubo/jobs/backend-engineer-b2d195', 'Backend Engineer ', 'CuboAi 智慧寶寶攝影機_雲云科技股份有限公司 ', ['Node.js', 'Python', 'GCP、AWS、Azure'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/clinico-f9741d/jobs/rd-software-backend-developer', '【RD】軟體後端工程師 (Backend Developer)', '科林儀器股份有限公司', ['Node.js', 'TypeScript', 'Framework'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/teamt5-org-tw/jobs/sonar-c-software-engineer', '【Sonar】C++ Endpoint Software Engineer | C++ 端點軟體工程師', '杜浦數位安全股份有限公司', ['C++', '通訊軟體工程師', '系統整合分析'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/teamt5-org-tw/jobs/backend-engineer-research-engineer', '【ND】後端工程師 / Backend Engineer / Research Engineer\xa0', '杜浦數位安全股份有限公司', ['Python', 'Golang', 'C'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/goodfinance/jobs/be4de7', ' 科技部_Senior Backend Engineer (Golang)', '美好證券 Good Finance', ['Golang', 'Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/goodfinance/jobs/c6a620', ' 科技部_Python 後端工程師', '美好證券 Good Finance', '', '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/mile.cloud/jobs/sr-backend-engineer-86755f', '資深後端工程師 Sr  Backend Engineer', 'CloudMile 萬里雲', ['backend', 'Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/mile.cloud/jobs/backend-engineer-bc549e', '後端工程師 Backend Engineer', 'CloudMile 萬里雲', ['backend', 'Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/mile.cloud/jobs/cloud-platform-product-team-backend-engineer', '[雲端平台產品團隊] 後端工程師 Backend Engineer', 'CloudMile 萬里雲', ['backend', 'Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/playsee/jobs/backend-development', 'Backend Developer', 'Playsee', ['golang', 'MySQL', 'NoSQL'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=8
# Success
# There are 10 jobs in this page.
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/fourdesire/jobs/4e6d49', ' 工程實習生 (Server) | Engineering Intern (Server)', 'Fourdesire', ['Engineer', 'Server', 'SQL'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/access-taiwan-lab/jobs/32db00', '日商 後端資深軟體開發工程師(4年以上經驗) Senior BE Elixir Developer (4 Years+)', 'ACCESS Taiwan Lab', ['elixir', 'python', 'golang'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/techdesign/jobs/taipei-backend-software-engineer', '[台北]Backend Engineer', 'TECHDesign', ['PHP', 'Python', 'JavaScript'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/kronos/jobs/full-time-senior-c-software-engineer', 'Senior Software Engineer, C++  資深C++軟體工程師', 'Kronos Research 麒點科技', ['C++', 'Python', 'Linux'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/stacs/jobs/back-end-software-engineer-c44a55', '後端技術工程師 (Back End Software Engineer)', '台灣賀思達科技有限公司', ['back-end', 'blockchain', 'MySQL'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/data-sci-info-about-e6-9c-a8-e5-88-bb-e6-80-9d/jobs/ebf642', 'Python 資深後端工程師 / Senior Backend Engineer (可遠端 WFH)', '木刻思股份有限公司', ['Docker', 'Django Framework', 'Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/bf68ed/jobs/71b873', '解決方案系統開發工程師/資深工程師(遠創智慧)', '遠通電收股份有限公司', ['PL/SQL', 'Java', 'JavaScript'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/h2-inc/jobs/jr-sr-backend-engineer-backend-engineer', 'Mid. - Sr. 後端工程師 Backend Engineer', 'H2 Inc.', ['python', 'PostgreSQL', 'AWS'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/hytechs-au/jobs/4d6b78', 'Java Backend Developer JAVA後端開發工程師 (APP)', '海科科技有限公司', ['+spring boot', '+MySQL', '+Linux'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/ezprice/jobs/2b80c7', 'Senior Backend Engineer | 資深後端工程師 (invos發票存摺)', '麻布數據科技股份有限公司', ['GCP', 'AWS', 'Microservice'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=9
# Success
# There are 10 jobs in this page.
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/udngroup/jobs/83b491', '【行動發展部】後端工程師(替代役可)', '聯合報股份有限公司', '', '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/roboadvisor/jobs/backend-engineer-787e7f', 'Python後端工程師', '阿爾發證券投資顧問股份有限公司', ['Python', 'SQL', 'Github'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/ezprice/jobs/519c36', 'Senior Backend Engineer  | 資深後端工程師 (Moneybook 麻布記帳) ', '麻布數據科技股份有限公司', ['Python', 'TypeScript', 'Node.js'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/dsp-im/jobs/backend-engineer-d46250', '後端工程師', '智庫驅動股份有限公司', ['Django Framework', 'Python', 'PostgreSQL'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/aetherai/jobs/senior-backend-engineer-617f10', 'Senior Back-end Engineer', '雲象科技股份有限公司 aetherAI Co., Ltd', ['Python', 'RESTful', 'GraphQL'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/104-company-1a2x6bkuw3/jobs/python-backend-engineer-b4bbee', 'Python 後端工程師', '金冠科技有限公司', '', '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/arcadegalaxy-space/jobs/front-end-engineer-dd81eb', '後端工程師 Back-end Engineer', '第九商行', ['Backend Development', 'Backend Engineer', 'Golang'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/interagent/jobs/backend-engineer-8f6c4a', '後端工程師', '塔台智能網絡股份有限公司', ['Python', 'SaaS', '後端開發'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/walnutek/jobs/python-flask-web-backend-engineer', 'Python Flask網頁後端工程師 ', '核果智能科技股份有限公司', ['flask', 'python', 'linux'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/lucid/jobs/copy-sr-back-end-engineer-python', '資深後端工程師 Sr. Back-end Engineer (Python)', 'Lucid', ['backend engineer', 'Backend Service', 'Backend Development'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=10
# Success
# There are 10 jobs in this page.
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/kloudless-taiwan-inc/jobs/backend-engineer-security-posture-management', 'Backend Engineer, Security Posture Management ', 'Kloudless, a Netskope company', ['Distributed Systems', 'Python', 'CI/CD'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/doubleits/jobs/recruitment-python-developer', '【代招】Python Developer', '多博科技', '', '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/nogle-taiwan/jobs/junior-software-developer', 'Junior Software Developer', 'Nogle Taiwan ', ['Java', 'Python', 'C++'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# ...
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/symphox.net/jobs/bfc7f2', '[小樹購] 測試工程師 SDET Engineer(Junior/Senior )', '神坊資訊股份有限公司', ['Postman for API', 'Shell Script', 'Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/symphox.net/jobs/xiaoshubu-test-engineer-sqa-engineer-junior-senior', '[小樹購] 測試工程師 SQA Engineer(Junior/Senior )', '神坊資訊股份有限公司', ['Python', 'Django', 'Flask'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/teamt5-org-tw/jobs/quality-assurance-engineer-4fbf48', '軟體測試工程師 Quality Assurance Engineer ', '杜浦數位安全股份有限公司', ['Python', 'Linux', 'Shell'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/alfred-camera/jobs/engineer-sdet', 'SDET / 軟體測試開發工程師', 'Alfred Systems Inc. 阿福管家 - 用舊手機做監控攝影機', ['Appium', 'Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_qa-test-engineer&order=latest&page=4
# Success
# There are 10 jobs in this page.
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/txone-networks/jobs/engineer-in-test-temp', 'Engineer in Test (Temp)', 'TXOne Networks Inc. 睿控網安股份有限公司', '', '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/zealogics-it-solutions/jobs/automation-test-engineer-258773', '(Sr.) Automation Test Engineer', 'Zealogics IT Solutions 美商邏輯技術有限公司', ['Python', 'Robot Framework', 'Test Automation'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/trendmicro/jobs/sr-software-engineer-in-test-ics-security', 'Sr. Software Engineer in Test (ICS Security)', '趨勢科技 TrendMicro', ['QA Engineer', 'Automation Testing', 'Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/funnow/jobs/product-test-engineer-sqa-engineer', '產品測試工程師 QA Engineer', 'FunNow - 即時預訂都會享樂的第一選擇', ['QA Engineer', 'JMeter', 'SQL'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/ghtinc-tw/jobs/0f4dac', '【研究發展處】SQA Engineer / 自動測試工程師 / 資料驗證 ', '現觀科技股份有限公司', ['Linux', 'Python', 'SQL'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/facebook-ambernetwork/jobs/test-engineer-9555b7', '測試工程師', '安璞資訊', '', '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/cruisys/jobs/SQA', 'Software QA Automation Engineer 軟體自動化測試工程師', 'CRUISYS 巡辰股份有限公司', ['QA', 'Selenium', 'Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/alphabit-fintech/jobs/quality-assurance-engineer-1dacf0', 'Quality Assurance Engineer', 'Alphabit Fintech 阿爾法比特科技有限公司', ['AWS', 'Java', 'Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/104-company-1a2x6blum7/jobs/qa-engineer-8312e3', 'QA工程師', 'Ymir 尤米爾科技有限公司', ['Python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/insightxcareer/jobs/software-test-engineer-automation-test-engineer', '軟體測試工程師 / 自動化測試工程師', '創宇管理顧問有限公司', ['Testing', 'Testing Engineer', 'Testing Tool'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_qa-test-engineer&order=latest&page=5
# Success
# There are 10 jobs in this page.
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/lilee-systems/jobs/software-qa-engineer-73f085', '軟體測試工程師 Software QA Engineer', 'Lilee Systems ', ['Linux', 'Python', 'Selenium'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/linc/jobs/senior-software-quality-assurance-engineer-0c57a3', 'Senior Software Quality Assurance Engineer', 'Linc', ['python development', 'JavaScript'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/104-company-1a2x6blcto/jobs/qa-automation-engineer-28ca1e', '自動化測試工程師 QA Automation Engineer', '木葉訊息技術有限公司', ['MySQL', 'Redis', 'Mongo'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/friday-_-421a35/jobs/yuan-chuan-friday-shopping-software-test-engineer', '遠傳friDay購物 - 軟體測試工程師 ', '遠傳friDay購物_遠時數位科技股份有限公司', ['QA', 'QA Engineer', 'QA testing軟體測試'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/barco-en/jobs/cea72c', ' Senior Software Development Engineer in Test', ' 巴可股份有限公司', ['Mac OS', 'Android', 'iOS'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/hcl-technologies-taiwan-ltd/jobs/embedded-automation-engineer-python', 'Embedded Automation Engineer, Python', 'HCL TECHNOLOGIES (TAIWAN) LTD.', '', '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/yuling-intl/jobs/test-engineer-494bd8', '測試工程師 (Quality Assurance)', '宇林國際科技顧問有限公司', ['Python', 'QA Engineer', 'AWS'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/neithnet/jobs/automation-test-engineer-1b2471', '自動化測試工程師', '騰曜網路科技股份有限公司', ['Linux', 'Python', 'JavaScript'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/atgames-net/jobs/automation-qa-engineer', '自動化測試工程師 (Automation QA Engineer)', '愛勝遊戲股份有限公司', ['Linux', 'Java', 'python'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/fc6a27/jobs/test-engineer-b30270', '測試工程師', '代碼科技有限公司', '', '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# https://www.cakeresume.com/jobs/python?profession%5B0%5D=management-business_data-analyst&order=latest
# Success
# There are 7 jobs in this page.
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/mexctaiwan/jobs/risk-control-data-analyst', '風控數據分析師', 'MEXC Taiwan', '', '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/cmoney/jobs/operational-data-analyst', '營運數據分析師', 'CMoney全曜財經資訊股份有限公司', ['#Python', '#SQL', 'excel'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/udngroup/jobs/ee60a9', '【總管理處數據發展部】數據分析師 - (數據分析)', '聯合報股份有限公司', ['SQL', 'Google Cloud Platform', 'Google Analytics'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/udngroup/jobs/data-development-department-data-engineer', '【總管理處數據發展部】-  資料工程師', '聯合報股份有限公司', ['SQL', 'Google Cloud Platform', 'Google Analytics'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/1111-corp-75132061/jobs/business-analyst-609358', 'Business Analyst 商業分析師', '卓亞國際人力資源顧問有限公司(內部徵才)', ['Google Tag Manager', 'Google Analytics', 'Optimize'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/skm/jobs/member-data-analysis-specialist-head-office', ' CRM會員數據分析專員(總公司)', '新光三越百貨股份有限公司', ['+Python', '+SQL', '+PowerBI'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']
# type: 5  label: 5
# {'user': '1・Full-time・Mid-Senior level', 'map-marker-alt': '台灣台北', 'dollar-sign': '90K ~ 150K TWD / month', 'business-time': '3 years of experience required', 'sitemap': 'Managing 1-5 staff'}
# ['https://www.cakeresume.com/companies/lulainno/jobs/data-analyst-data-analyst-6f4f67', '數據分析師 - Data Analyst', '塶樂微創有限公司', ['Matlab', 'Python', 'MS SQL'], '1・Full-time・Mid-Senior level', '台灣台北', '90K ~ 150K TWD / month', '3 years of experience required', 'Managing 1-5 staff']

# %%
url_data
# Out:
# ['https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=2',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=3',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=4',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=5',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=6',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=7',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=8',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=9',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=10',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=11',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=12',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=13',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_back-end-engineer&order=latest&page=14',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest&page=2',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest&page=3',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest&page=4',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest&page=5',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest&page=6',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-engineer&order=latest&page=7',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-scientist&order=latest',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-scientist&order=latest&page=2',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-scientist&order=latest&page=3',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-scientist&order=latest&page=4',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_data-scientist&order=latest&page=5',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_machine-learning-engineer&order=latest',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_machine-learning-engineer&order=latest&page=2',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_qa-test-engineer&order=latest',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_qa-test-engineer&order=latest&page=2',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_qa-test-engineer&order=latest&page=3',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_qa-test-engineer&order=latest&page=4',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=it_qa-test-engineer&order=latest&page=5',
#  'https://www.cakeresume.com/jobs/python?profession%5B0%5D=management-business_data-analyst&order=latest']
